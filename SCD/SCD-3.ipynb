# %%
from sqlalchemy import create_engine
from sqlalchemy.sql import text
import pandas as pd
import numpy as np

# %%
engine=create_engine(
        "mssql+pyodbc://DESKTOP-R5LFETM\SQLEXPRESS/Customers?driver=ODBC+Driver+17+for+SQl+Server&trusted_connection=yes"

)

# %%
conn=engine.connect()

# %%
df=pd.read_csv(r'C:\Users\Krishna\Desktop\Python\SSMS\us_customer_data.csv')
df=df.drop('Unnamed: 0',axis=1)

# %%
df=df.head(10)

# %%
df.head(1)
# Out:
#    customer_id           name               email            phone  \
# 0            1  Michelle Kidd  vayala@example.net  +971 6197234258
#
#                        address registration_date loyalty_status code
# 0  USNS Santiago, FPO AE 80872        2025-01-25           Gold  971

# %%
df['old_name']=np.nan
df['old_mail']=np.nan
df['old_phone']=np.nan
df['old_add']=np.nan

# %%
df['last_update']=pd.NaT

# %%
df.head(2)
# Out:
#    customer_id           name                        email            phone  \
# 0            1  Michelle Kidd           vayala@example.net  +971 6197234258
# 1            2    Brad Newton  taylorcatherine@example.net  +356 5376741158
#
#                                              address registration_date  \
# 0                        USNS Santiago, FPO AE 80872        2025-01-25
# 1  38783 Oliver Street, West Kristenborough, MT 9...        2023-07-13
#
#   loyalty_status code  old_name  old_mail  old_phone  old_add last_update
# 0           Gold  971       NaN       NaN        NaN      NaN         NaT
# 1         Silver  356       NaN       NaN        NaN      NaN         NaT

# %% [markdown]
# run from here

# %%
df=pd.read_csv(r'C:\Users\Krishna\Desktop\Python\SCD\scd3.csv')
df=df.drop('Unnamed: 0',axis=1)

# %%
id=int(input('enter id'))
name=input("enter name")
mail=input('enter mail')
phone=input('enter phone number')
add=input('enter address')

# %%
row=df[df['customer_id']==id].index
i=row[0]
i
# Out:
# np.int64(2)

# %%
df
# Out:
#    customer_id                   name                        email  \
# 0            1          Michelle Kidd           vayala@example.net
# 1            2            Brad Newton  taylorcatherine@example.net
# 2            3           Larry Torres         dsanchez@example.net
# 3            4         Kimberly Price    jessicaknight@example.com
# 4            5       Matthew Phillips        qwilliams@example.com
# 5            6  Darrell Gallagher DVM      larryharris@example.org
# 6            7           Louis Miller  patriciaelliott@example.org
# 7            8    Melissa Galloway MD   watsonbenjamin@example.net
# 8            9         Matthew Harvey          bgaines@example.net
# 9           10           Rachel White     whitemichael@example.org
#
#              phone                                            address  \
# 0  +971 6197234258                        USNS Santiago, FPO AE 80872
# 1  +356 5376741158  38783 Oliver Street, West Kristenborough, MT 9...
# ...

# %%
if df.loc[i,'name']!=name:
    df.loc[i,'old_name']=df.loc[i,'name']
    df.loc[i,'name']=name
if df.loc[i, 'email'] != mail:
    df.loc[i, 'old_mail'] = df.loc[i, 'email']
    df.loc[i, 'email'] = mail
if df.loc[i,'phone']!=phone:
    df.loc[i,'old_phone']=df.loc[i,'phone']
    df.loc[i,'phone']=phone
if df.loc[i,'address']!=add:
    df.loc[i,'old_add']=df.loc[i,'address']
    df.loc[i,'address']=add
df.loc[i,'last_update']=pd.Timestamp.now()
# Out:
# C:\Users\Krishna\AppData\Local\Temp\ipykernel_32640\415728817.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Larry Torres' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i,'old_name']=df.loc[i,'name']
# C:\Users\Krishna\AppData\Local\Temp\ipykernel_32640\415728817.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'dsanchez@example.net' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i, 'old_mail'] = df.loc[i, 'email']
# ...

# %%
df
# Out:
#    customer_id                   name                        email  \
# 0            1          Michelle Kidd           vayala@example.net
# 1            2            Brad Newton  taylorcatherine@example.net
# 2            3                Krishna                abc@gmail.com
# 3            4         Kimberly Price    jessicaknight@example.com
# 4            5       Matthew Phillips        qwilliams@example.com
# 5            6  Darrell Gallagher DVM      larryharris@example.org
# 6            7           Louis Miller  patriciaelliott@example.org
# 7            8    Melissa Galloway MD   watsonbenjamin@example.net
# 8            9         Matthew Harvey          bgaines@example.net
# 9           10           Rachel White     whitemichael@example.org
#
#              phone                                            address  \
# 0  +971 6197234258                        USNS Santiago, FPO AE 80872
# 1  +356 5376741158  38783 Oliver Street, West Kristenborough, MT 9...
# ...

# %%
df.to_csv(r'C:\Users\Krishna\Desktop\Python\SCD\scd3.csv')
